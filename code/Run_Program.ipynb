# %% [markdown]
# # **Insulator detection from aerial Images**
#
# Upload the Code files on google drive.
#
# This Jupyter notebook will simply enable the program files to run using google collab servers to perform training

# %% [markdown]
# ## Training module
#
# This segment of the code would train your model and upload

# %%
# To enable this jupyter notebook to access files from your local google drive
from google.colab import drive
drive.mount("/content/gdrive")

# %% [markdown]
# To setup all the requirements, run the file requirements.txt file in the root directory.

# %%
# !pip install -r '/content/gdrive/My Drive/Code/requirements.txt'

# %% [markdown]
# The directories of the files from train_frcnn.py might have to be changed according to how the files have been uploaded.
#
# Few of the file locations might have to be changed in order to accomodate the change in directory during the upload.
#
# Currently the program is configured to run on ResNet50, In order to change the CNN, please change the line 18 in train_frcnn.py file
# to inherit vgg.py instead of resnet.py.

# %%
# !python3 '/content/gdrive/My Drive/Code/train_frcnn.py'

# %% [markdown]
# ## Testing Module
#
# This segment loads the weights trained from the above training module and process the image
#
# The particular file/folder to be tested could be changed in the predict.py file

# %%
# !python3 '/content/gdrive/My Drive/code/predict.py'
